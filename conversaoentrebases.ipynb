# %% [markdown]
# <a href="https://colab.research.google.com/github/severopaiva/matem-ticaenem/blob/main/conversaoentrebases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A conversão entre bases é uma necessidade comum para quem trabalha com TI
# Este programa faz a conversão entre várias bases diferentes

def potencia(base,expoente):
    if expoente == 0:
       return 1
    else:
       return (base * potencia (base,expoente-1))

def divide (num,divi):
    global quoc
    quoc = num // divi
    resto = num % divi
    return resto

def testahexa(quoc):
    if quoc >= 10:
       if quoc == 10:
          x = "A"
       elif quoc == 11:
          x = "B"
       elif quoc == 12:
          x = "C"
       elif quoc == 13:
          x = "D"
       elif quoc == 14:
          x = "E"
       elif quoc == 15:
          x = "F"
    else:
       x = str (quoc)
    return x

def convbindec(binario):
    while (binario != "0"):
       listabin = list(binario)
       decimal = 0
       exp1 = len(listabin)
       for i in listabin:
          exp1 = exp1 - 1
          decimal = decimal + (int(i) * potencia (2,exp1))
       print ("O binário ", binario, "vale ", decimal, " na base 10")
       print()
       binario = input("Digite um número binário: ")
    print ()
    print ("Fim de conversão!")
    return
    

def convdecbinario(deci):
    divisor = 2
    global quoc
    quoc = 1
    while (deci != 0):
        resto = divide (deci,divisor)
        numbin = "" + str(resto)
        while (quoc >= divisor):
           numbin = str (divide (quoc,divisor)) + numbin
        numbin = str (quoc) + numbin 
        print ("O decimal ", deci, " vale ", numbin, " na base ",divisor)
        print()
        deci = int(input("Digite um número decimal: "))
    print ()
    print ("Fim de conversão!")
    return

def convoctaldec(decimal):
    base = 8
    while (numero != "0"):
       lista = list(numero)
       decimal = 0
       exp1 = len(lista)
       for i in lista:
          exp1 = exp1 - 1
          decimal = decimal + (int(i) * potencia (base,exp1))
       print ("O Octal ", numero, "vale ", decimal, " na base 10")
       print()
       numero = input("Digite um número Octal: ")
    print ()
    print ("Fim de conversão!")
    return

def convdecoctal(deci):
    divisor = 8
    global quoc
    quoc = 1
    while (deci != 0):
        resto = divide (deci,divisor)
        numbin = "" + str(resto)
        while (quoc >= divisor):
           numbin = str (divide (quoc,divisor)) + numbin
        numbin = str (quoc) + numbin 
        print ("O decimal ", deci, " vale ", numbin, " na base ",divisor)
        print()
        deci = int(input("Digite um número decimal: "))
    print ()
    print ("Fim de conversão!")
    return

def convhexadec(numero):
    base = 16
    while (numero != "0"):
       lista = list(numero)
       decimal = 0
       exp1 = len(lista)
       for i in lista:
          exp1 = exp1 - 1
          if i == "a" or i == "A":
              x = 10
          elif i == "b" or i == "B":
              x = 11
          elif i == "c" or i == "C":
              x = 12
          elif i == "d" or i == "D":
              x = 13
          elif i == "e" or i == "E":
              x = 14
          elif i == "f" or i == "F":
              x = 15
          else:
              x = int (i)
          decimal = decimal + (int(x) * potencia (base,exp1))
       print ("O Hexadecimal ", numero, "vale ", decimal, " na base 10")
       print()
       numero = input("Digite um número Hexadecimal: ")
    print ()
    print ("Fim de conversão!")
    return

def convdechexa(deci):
    divisor = 16
    global quoc
    quoc = 1
    while (deci != 0):
        resto = divide (deci,divisor)
        numero = "" + str(testahexa(resto))
        while (quoc >= divisor):
           numero = str (testahexa(divide (quoc,divisor))) + numero
        numero = testahexa((quoc)) + numero 
        print ("O decimal ", deci, " vale ", numero, " na base ",divisor)
        print()
        deci = int(input("Digite um número decimal: "))
    print ()
    print ("Fim de conversão!")
    return


op = 1
global quoc
quoc = 1
resto = 1
while (op != 0):
    print ("Conversões Possíveis: ")
    print ("1 - Binário para Decimal ")
    print ("2 - Decimal para Binário")
    print ("3 - Octal para decimal")
    print ("4 - Decimal para Octal")
    print ("5 - Hexadecimal para decimal")
    print ("6 - Decimal para Hexadecimal")
    print ("0 - Sair")
    op = int(input("Sua opção: "))
    if op == 1:
       print()
       print ("Conversão de binário para decimal")
       print()
       binario = input("Digite um número binário: ")
       convbindec(binario)
    elif op == 2:
       print()
       print ("Conversão de decimal para binário")
       print()
       deci = int(input("Digite um número decimal: "))
       convdecbinario(deci)
    elif op == 3:
       print()
       print ("Conversão de Octal para decimal")
       print()
       numero = input("Digite um número Octal: ")
       convoctaldec(numero)
    elif op == 4:
       print()
       print ("Conversão de decimal para Octal")
       print()
       deci = int(input("Digite um número decimal: "))
       convdecoctal()
    elif op == 5:
       print()
       print ("Conversão de Hexa para decimal")
       print()
       numero = input("Digite um número Hexadecimal: ")
       convhexadec(numero)
    elif op == 6:
       print()
       print ("Conversão de decimal para Hexadecimal")
       print()
       deci = int(input("Digite um número decimal: "))
       convdechexa(deci)
    else:
       exit
# Out:
# Conversões Possíveis:
# 1 - Binário para Decimal
# 2 - Decimal para Binário
# 3 - Octal para decimal
# 4 - Decimal para Octal
# 5 - Hexadecimal para decimal
# 6 - Decimal para Hexadecimal
# 0 - Sair
# Sua opção: 2
#
# Conversão de decimal para binário
#
# Digite um número decimal: 256
# O decimal  256  vale  100000000  na base  2
#
# Digite um número decimal: 0
#
# Fim de conversão!
# Conversões Possíveis:
# 1 - Binário para Decimal
# 2 - Decimal para Binário
# 3 - Octal para decimal
# 4 - Decimal para Octal
# 5 - Hexadecimal para decimal
# 6 - Decimal para Hexadecimal
# 0 - Sair
# Sua opção: 0
